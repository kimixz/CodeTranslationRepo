# %%
import os
import json
from tree_sitter_languages import get_parser

# %%
def extract_ast_info(node, method_data):
    if node.type == 'method_declaration':
        if 'methods' not in method_data:
            method_data['methods'] = []
            
        method_info = {}
        
        method_name_node = node.child_by_field_name('name')
        if method_name_node:
            method_info['name'] = method_name_node.text.decode('utf-8')
            
        return_type_node = node.child_by_field_name('type')
        if return_type_node:
            method_info['return_type'] = return_type_node.text.decode('utf-8')
            
        parameters_node = node.child_by_field_name('parameters')
        if parameters_node:
            method_info['parameters'] = []
            for param in parameters_node.named_children:
                if param.type == 'formal_parameter':
                    param_type = param.child_by_field_name('type')
                    param_name = param.child_by_field_name('name')
                    if param_type and param_name:
                        method_info['parameters'].append({
                            'type': param_type.text.decode('utf-8'),
                            'name': param_name.text.decode('utf-8')
                        })

        method_info['start_position'] = node.start_byte
        method_info['end_position'] = node.end_byte
        
        body_node = node.child_by_field_name('body')
        if body_node:
            method_info['body_start'] = body_node.start_byte
            method_info['body_end'] = body_node.end_byte
        
        method_data['methods'].append(method_info)
        
    if node.type.endswith('_statement'):
        if 'code_constructs' not in method_data:
            method_data['code_constructs'] = []
        if node.type not in method_data['code_constructs']:
            method_data['code_constructs'].append(node.type)
    
    if node.type == 'method_invocation':
        method_name_node = node.child_by_field_name('name')
        receiver_node = node.child_by_field_name('object')
        
        if method_name_node:
            method_name = method_name_node.text.decode('utf-8')
            if 'method_calls' not in method_data:
                method_data['method_calls'] = {}
            
            class_name = 'unknown'
            if receiver_node:
                class_name = receiver_node.text.decode('utf-8')
                
            if class_name not in method_data['method_calls']:
                method_data['method_calls'][class_name] = []
            if method_name not in method_data['method_calls'][class_name]:
                method_data['method_calls'][class_name].append(method_name)
    
    if node.type == 'local_variable_declaration':
        declarators = node.named_children[1:]
        type_node = node.child_by_field_name('type')
        if type_node:
            class_name = type_node.text.decode('utf-8')
            for declarator in declarators:
                variable_node = declarator.child_by_field_name('name')
                if variable_node:
                    variable_name = variable_node.text.decode('utf-8')
                    if 'local_variables' not in method_data:
                        method_data['local_variables'] = {}
                    method_data['local_variables'][variable_name] = class_name
    
    for child in node.children:
        extract_ast_info(child, method_data)

def process_java_file(file_path, output_dir):
    with open(file_path, 'r') as file:
        java_code = file.read()
    tree = parser.parse(java_code.encode())

    ast_info={}
    extract_ast_info(tree.root_node, ast_info)

    file_name = os.path.splitext(os.path.basename(file_path))[0]
    output_file = os.path.join(output_dir, f"{file_name}_ast.json")
    os.makedirs(output_dir, exist_ok=True)
    with open(output_file, 'w') as f:
        json.dump(ast_info, f, indent=4)

def main(repo_path, output_dir):
    for root, dirs, files in os.walk(repo_path):
        for file in files:
            if file.endswith('.java'):
                file_path = os.path.join(root, file)
                process_java_file(file_path, output_dir)

if __name__ == "__main__":
    parser = get_parser('java') 
    base_path = "../../../"
    repo_path = f"{base_path}dataset/{project_name}"  
    output_dir = f"{base_path}output/{project_name}/AST"  
    main(repo_path, output_dir)
# Out:
# Processing ../../../dataset/NextCloud/app/src/androidTest/disabledTests/AuthenticatorActivityTest.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/disabledTests/uiautomator/InitialTest.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/nextcloud/client/UploadListActivityActivityIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/nextcloud/client/CommunityActivityIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/nextcloud/client/AuthenticatorActivityIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/nextcloud/client/FirstRunActivityIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/nextcloud/client/EndToEndAction.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/nextcloud/client/SyncedFoldersActivityIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/nextcloud/client/account/UserAccountManagerImplTest.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/nextcloud/client/account/OwnCloudClientManagerTest.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/AbstractIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/ScreenshotsIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/UploadIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/DownloadIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/AbstractOnServerIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/FileIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/ui/activity/FolderPickerActivityIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/ui/activity/ManageAccountsActivityIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/ui/activity/DrawerActivityIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/ui/activity/FileDisplayActivityTest.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/ui/activity/ConflictsResolveActivityIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/ui/activity/UserInfoActivityIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/ui/dialog/DialogFragmentIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/util/EncryptionTestIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/util/ErrorMessageAdapterIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/operations/RemoveFileOperationIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/datamodel/FileDataStorageManagerIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/datamodel/OCFileUnitTest.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/datamodel/FileDataStorageManagerContentProviderClientIT.java
# Processing ../../../dataset/NextCloud/app/src/androidTest/java/com/owncloud/android/datamodel/UploadStorageManagerTest.java
# Processing ../../../dataset/NextCloud/app/src/huawei/java/com/nextcloud/client/di/VariantComponentsModule.java
# Processing ../../../dataset/NextCloud/app/src/huawei/java/com/owncloud/android/utils/PushUtils.java
# Processing ../../../dataset/NextCloud/app/src/huawei/java/com/owncloud/android/utils/SecurityUtils.java
# Processing ../../../dataset/NextCloud/app/src/test/java/com/nextcloud/client/preferences/TestAppPreferences.java
# Processing ../../../dataset/NextCloud/app/src/test/java/com/owncloud/android/ui/activity/SyncedFoldersActivityTest.java
# Processing ../../../dataset/NextCloud/app/src/test/java/com/owncloud/android/ui/adapter/ActivityListAdapterTest.java
# Processing ../../../dataset/NextCloud/app/src/test/java/com/owncloud/android/ui/adapter/UserListAdapterTest.java
# Processing ../../../dataset/NextCloud/app/src/test/java/com/owncloud/android/ui/activities/ActivitiesPresenterTest.java
# Processing ../../../dataset/NextCloud/app/src/test/java/com/owncloud/android/ui/activities/data/files/RemoteFilesRepositoryTest.java
# Processing ../../../dataset/NextCloud/app/src/test/java/com/owncloud/android/ui/activities/data/activities/RemoteActivitiesRepositoryTest.java
# Processing ../../../dataset/NextCloud/app/src/test/java/com/owncloud/android/utils/OwnCloudSessionTest.java
# Processing ../../../dataset/NextCloud/app/src/test/java/com/owncloud/android/utils/StringUtilsTest.java
# Processing ../../../dataset/NextCloud/app/src/test/java/com/owncloud/android/utils/DisplayUtilsTest.java
# Processing ../../../dataset/NextCloud/app/src/test/java/com/owncloud/android/authentication/AuthenticatorDataUrlTest.java
# Processing ../../../dataset/NextCloud/app/src/test/java/com/owncloud/android/authentication/AuthenticatorUrlUtilsTest.java
# Processing ../../../dataset/NextCloud/app/src/qa/java/com/nextcloud/client/di/VariantComponentsModule.java
# Processing ../../../dataset/NextCloud/app/src/qa/java/com/owncloud/android/utils/PushUtils.java
# Processing ../../../dataset/NextCloud/app/src/qa/java/com/owncloud/android/utils/SecurityUtils.java
# Processing ../../../dataset/NextCloud/app/src/release/java/com/nextcloud/client/di/BuildTypeComponentsModule.java
# Processing ../../../dataset/NextCloud/app/src/gplay/java/com/nextcloud/client/di/VariantComponentsModule.java
# Processing ../../../dataset/NextCloud/app/src/gplay/java/com/owncloud/android/utils/PushUtils.java
# Processing ../../../dataset/NextCloud/app/src/gplay/java/com/owncloud/android/utils/SecurityUtils.java
# Processing ../../../dataset/NextCloud/app/src/gplay/java/com/owncloud/android/authentication/ModifiedAuthenticatorActivity.java
# Processing ../../../dataset/NextCloud/app/src/gplay/java/com/owncloud/android/services/firebase/NCFirebaseMessagingService.java
# Processing ../../../dataset/NextCloud/app/src/generic/java/com/nextcloud/client/di/VariantComponentsModule.java
# Processing ../../../dataset/NextCloud/app/src/generic/java/com/owncloud/android/utils/PushUtils.java
# Processing ../../../dataset/NextCloud/app/src/generic/java/com/owncloud/android/utils/SecurityUtils.java
# Processing ../../../dataset/NextCloud/app/src/main/java/third_parties/aosp/SQLiteTokenizer.java
# Processing ../../../dataset/NextCloud/app/src/main/java/third_parties/sufficientlysecure/AndroidCalendar.java
# Processing ../../../dataset/NextCloud/app/src/main/java/third_parties/sufficientlysecure/DuplicateHandlingEnum.java
# Processing ../../../dataset/NextCloud/app/src/main/java/third_parties/sufficientlysecure/ProcessVEvent.java
# Processing ../../../dataset/NextCloud/app/src/main/java/third_parties/sufficientlysecure/SaveCalendar.java
# Processing ../../../dataset/NextCloud/app/src/main/java/third_parties/sufficientlysecure/CalendarSource.java
# Processing ../../../dataset/NextCloud/app/src/main/java/third_parties/daveKoeller/AlphanumComparator.java
# Processing ../../../dataset/NextCloud/app/src/main/java/third_parties/ezvcard_android/ContactOperations.java
# Processing ../../../dataset/NextCloud/app/src/main/java/third_parties/ezvcard_android/DataMappings.java
# Processing ../../../dataset/NextCloud/app/src/main/java/third_parties/ezvcard_android/AndroidCustomField.java
# Processing ../../../dataset/NextCloud/app/src/main/java/org/nextcloud/providers/cursors/RootCursor.java
# Processing ../../../dataset/NextCloud/app/src/main/java/org/nextcloud/providers/cursors/FileCursor.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/android/sso/PlainHeader.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/android/sso/Response.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/android/sso/PatchMethod.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/android/sso/InputStreamBinder.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/android/sso/QueryParam.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/android/sso/Constants.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/android/sso/aidl/IThreadListener.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/android/sso/aidl/NextcloudRequest.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/android/sso/aidl/ParcelFileDescriptorUtil.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/database/migrations/LegacyMigrationHelper.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/preferences/AppPreferencesImpl.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/preferences/DarkMode.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/preferences/AppPreferences.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/preferences/PreferencesModule.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/di/AppModule.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/di/InjectorNotFoundException.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/di/ComponentsModule.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/di/Injectable.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/di/AppComponent.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/di/package-info.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/network/ConnectivityServiceImpl.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/network/ClientFactoryImpl.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/network/ConnectivityService.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/network/NetworkModule.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/network/ClientFactory.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/account/CurrentAccountProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/account/UserAccountManager.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/nextcloud/client/account/UserAccountManagerImpl.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/MainApp.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/EmptyRecyclerView.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/SquareLinearLayout.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/ThemeableSwitchPreference.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/StatusDrawable.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/TextDrawable.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/AvatarGroupLayout.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/SquareImageView.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/decoration/MediaGridItemDecoration.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/decoration/SimpleListItemDividerDecoration.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/RichDocumentsLoadUrlTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/TextEditorLoadUrlTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/DeleteNotificationTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/CheckRemoteWipeTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/CheckAvailableSpaceTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/DeleteAllNotificationsTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/RetrieveHoverCardAsyncTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/NotificationExecuteActionTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/PrintAsyncTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/CopyAndUploadContentUrisTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/GallerySearchTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/LoadingVersionNumberTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/LoadContactsTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/asynctasks/FetchRemoteFileTask.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/RequestCredentialsActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/ToolbarActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/SsoGrantPermissionActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/UserInfoActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/OnEnforceableRefreshListener.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/ErrorsWhileCopyingHandlerActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/FileActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/FileDisplayActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/UploadListActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/ComponentsGetter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/UploadFilesActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/DrawerActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/ShareActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/BaseActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/ContactsPreferenceActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/ManageAccountsActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/StorageMigration.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/EditorWebView.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/ReceiveExternalFilesActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/SettingsActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activity/ExternalSiteWebView.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/OCFileListAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/StickyHeaderAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/ProgressListener.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/LinkShareViewHolder.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/ActivityAndVersionListAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/FileDetailTabAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/TemplateAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/PrintAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/UserListAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/SslCertificateViewAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/FilterableListAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/FeaturesWebViewAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/UploadListAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/SendButtonAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/UserListItem.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/ActivityListAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/RichDocumentsTemplateAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/ShareeListAdapterListener.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/FeaturesViewAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/NewLinkShareViewHolder.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/ShareViewHolder.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/LocalFileListAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/SslErrorViewAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/DiskLruImageCache.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/InternalShareViewHolder.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/CertificateCombinedExceptionViewAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/ViewType.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/ShareeListAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/StoragePathItem.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/NotificationListAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/X509CertificateViewAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/adapter/TrashbinListAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/whatsnew/ProgressIndicator.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/dialog/SsoWebView.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/dialog/parcel/SyncedFolderParcelable.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/components/SendButtonData.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/FeatureFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/FileDetailsSharingMenuBottomSheetActions.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/QuickSharingPermissionsBottomSheetDialog.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/FileDetailFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/TaskRetainerFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/FileDetailSharingMenuBottomSheetDialog.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/FileDetailActivitiesFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/LocalFileListFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/OCFileListFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/OCFileListBottomSheetActions.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/FeatureWebFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/ExtendedListFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/OCFileListBottomSheetDialog.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/GalleryFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/FileFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/FileDetailSharingFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/util/FileDetailSharingFragmentHelper.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/util/SharingMenuHelper.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/contactsbackup/BackupListFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/contactsbackup/ContactsAccount.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/contactsbackup/CalendarItemViewHolder.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/fragment/contactsbackup/VCardComparator.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/StickyHeaderItemDecoration.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/ActivitiesPresenter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/ActivitiesContract.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/ActivitiesActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/data/files/FilesRepository.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/data/files/RemoteFilesRepository.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/data/files/FilesServiceApi.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/data/files/FileRepositories.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/data/files/FilesServiceApiImpl.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/data/activities/ActivitiesServiceApi.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/data/activities/RemoteActivitiesRepository.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/data/activities/ActivitiesRepository.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/data/activities/ActivityRepositories.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/activities/data/activities/ActivitiesServiceApiImpl.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/preview/PreviewTextStringFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/preview/FileDownloadFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/preview/PreviewTextFileFragment.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/helpers/FileOperationsHelper.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/helpers/SparseBooleanArrayParcelable.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/notifications/NotificationsContract.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/notifications/NotificationUtils.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/interfaces/VersionListInterface.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/interfaces/ActivityListInterface.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/interfaces/TrashbinActivityInterface.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/interfaces/LocalFileListFragmentInterface.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/ui/interfaces/OCFileListFragmentInterface.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/providers/DocumentsStorageProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/providers/DiskLruImageCacheFileProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/providers/UsersAndGroupsSearchProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/providers/FileContentProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/features/FeatureItem.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/ErrorMessageAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/NextcloudServer.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/StringUtils.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/ThemeUtils.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/OwnCloudSession.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/BitmapUtils.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/FilesSyncHelper.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/DataHolderUtil.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/FileUtil.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/ScreenshotTest.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/EncryptionUtils.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/MimeTypeUtil.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/FileStorageUtils.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/DisplayUtils.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/ReceiversHelper.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/DeviceCredentialUtils.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/MimeType.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/DrawerMenuUtil.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/DialogMenuItem.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/svg/SvgBitmapTranscoder.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/svg/SvgOrImageDecoder.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/svg/SvgSoftwareLayerSetter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/svg/SVGorImage.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/svg/SvgDecoder.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/svg/SvgOrImageBitmapTranscoder.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/svg/SvgDrawableTranscoder.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/svg/MenuSimpleTarget.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/glide/CustomGlideUriLoader.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/glide/CustomGlideStreamLoader.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/theme/ThemeUtils.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/theme/CapabilityUtils.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/utils/theme/ThemeColorUtils.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/RenameFileOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/GetSharesForFileOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/CheckCurrentCredentialsOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/UpdateSharePermissionsOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/SynchronizeFolderOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/UpdateOCVersionOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/CommentFileOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/DetectAuthenticationMethodOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/UploadFileOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/GetServerInfoOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/SynchronizeFileOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/GetUserProfileOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/RemoveFileOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/UpdateNoteForShareOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/RichDocumentsCreateAssetOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/UploadException.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/RefreshFolderOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/UpdateShareInfoOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/RemoteOperationFailedException.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/MoveFileOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/CreateShareViaLinkOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/DownloadFileOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/RichDocumentsUrlOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/CopyFileOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/CreateShareWithShareeOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/GetCapabilitiesOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/UnshareOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/CreateFolderOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/UpdateShareViaLinkOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/operations/common/SyncOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/syncadapter/AbstractOwnCloudSyncAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/syncadapter/FileSyncService.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/syncadapter/FileSyncAdapter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/files/FileMenuFilter.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/files/StreamMediaFileOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/files/CreateFileFromTemplateOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/files/BootupBroadcastReceiver.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/files/FetchTemplateOperation.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/files/services/NameCollisionPolicy.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/files/services/IndexedForest.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/db/UploadResult.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/db/ProviderMeta.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/db/OCUpload.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datastorage/UniqueStorageList.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datastorage/StoragePoint.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datastorage/DataStorageProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datastorage/providers/IStoragePointProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datastorage/providers/VDCStoragePointProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datastorage/providers/MountCommandStoragePointProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datastorage/providers/AbstractCommandLineStoragePoint.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datastorage/providers/EnvironmentStoragePointProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datastorage/providers/AbstractStoragePointProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datastorage/providers/SystemDefaultStoragePointProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datastorage/providers/HardcodedStoragePointProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/jobs/OfflineSyncJob.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/UploadsStorageManager.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/DecryptedFolderMetadataOld.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/PushConfigurationState.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/SyncedFolderProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/FileDataStorageManager.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/VirtualFolderType.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/ThumbnailsCacheManager.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/SyncedFolder.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/FilesystemDataProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/ExternalLinksProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/ArbitraryDataProviderImpl.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/OCFile.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/SyncedFolderDisplayItem.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/FileSystemDataSet.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/MediaProvider.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/e2e/v1/decrypted/Sharing.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/e2e/v1/decrypted/DecryptedFolderMetadataFileV1.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/e2e/v1/decrypted/Data.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/e2e/v1/decrypted/Encrypted.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/e2e/v1/decrypted/DecryptedFile.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/e2e/v1/decrypted/DecryptedMetadata.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/datamodel/e2e/v1/encrypted/EncryptedFolderMetadataFileV1.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/authentication/LoginUrlInfo.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/authentication/AuthenticatorActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/authentication/AccountAuthenticatorService.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/authentication/AccountAuthenticatorActivity.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/authentication/AccountAuthenticator.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/services/SyncFolderHandler.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/services/AccountManagerService.java
# Processing ../../../dataset/NextCloud/app/src/main/java/com/owncloud/android/services/OperationsService.java
# Processing ../../../dataset/NextCloud/app/src/versionDev/java/com/nextcloud/client/di/VariantComponentsModule.java
# Processing ../../../dataset/NextCloud/app/src/versionDev/java/com/owncloud/android/utils/PushUtils.java
# Processing ../../../dataset/NextCloud/app/src/versionDev/java/com/owncloud/android/utils/SecurityUtils.java
